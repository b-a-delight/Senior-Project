# %%
import pandas as pd
import numpy as np
import xlrd
import os
import psutil
import sys
np.set_printoptions(threshold=np.inf)

# %%
#'W BOISE' : 'NORTH CENTRAL BENCH', 'WEST BOISE', 'WEST BOISE FREEWAY CORRIDOR'

#'BOISE BENCH' : 'CENTRAL BOISE BENCH', 'NORTH CENTRAL BENCH',  'BOISE BENCH FREEWAY CORRIDOR', 
#                'PARK & UNIVERSITY WATERFRONT'

#'W BOISE-MERIDIAN' : 'WEST BOISE', 'NORTHEAST MERIDIAN', 'WEST BOISE FREEWAY CORRIDOR', 'NORTH CENTRAL BENCH',
#                      'GARDEN CITY CHINDEN CORRIDOR', 'MERIDIAN FREEWAY CORRIDOR'

#'NORTH BOISE' : 'OLD NORTH BOISE', 'BOISE FOOTHILLS', 'NEW NORTH BOISE','DOWNTOWN BOISE', 'WARM SPRINGS',
#                'PARK & UNIVERSITY WATERFRONT'

#'SE BOISE' : 'NEW SOUTHEAST BOISE', 'SOUTHEAST BOISE INFILL','EAST BOISE WATERFRONT', 'OREGON TRAIL', 
#              'PARK & UNIVERSITY WATERFRONT', 'SOUTH BOISE DESERT'

#'NW BOISE-GARDEN CITY' : 'NEW NORTH BOISE', 'NORTHWEST BOISE', 'GARDEN CITY WATERFRONT', 'BOISE FOOTHILLS',
#                         'GARDEN CITY CHINDEN CORRIDOR']

#'NE BOISE' : 'BOISE FOOTHILLS', 'WARM SPRINGS', 'EAST BOISE WATERFRONT', 'BARBER & HARRIS RANCH'

#'SW BOISE' : 'WEST BOISE FREEWAY CORRIDOR', 'AIRPORT', 'BOISE BENCH FREEWAY CORRIDOR', 'SOUTH BOISE DESERT',
#              'SOUTHWEST BOISE'

#'SW BOISE-MERIDIAN': 'WEST BOISE FREEWAY CORRIDOR', 'MERIDIAN FREEWAY CORRIDOR', 'SOUTH MERIDIAN', 'SOUTHWEST BOISE'

# %%
house_df = pd.read_pickle('abvHouse.pkl')
jobs_df = pd.read_pickle('jobShift.pkl')
yearTotals = pd.read_pickle('yrTotalChange.pkl')

df = house_df

df = pd.merge(df, jobs_df, on = 'Year', how = 'left')
df = pd.merge(df, yearTotals, on = 'Year', how = 'left')

df = df.replace(np.nan,0)
df= df.drop(columns = ['All Occupations', 'TAV'])

df.to_pickle('AN_Build.pkl')
df
# Out:
#               Parcel       Year           Group         Neighborhood  \
# 0        R0017650020 2000-01-01  AARON PARK SUB  NORTH CENTRAL BENCH
# 1        R0017650030 2000-01-01  AARON PARK SUB  NORTH CENTRAL BENCH
# 2        R0017650040 2000-01-01  AARON PARK SUB  NORTH CENTRAL BENCH
# 3        R0017650050 2000-01-01  AARON PARK SUB  NORTH CENTRAL BENCH
# 4        R0027000008 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 5        R0027000013 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 6        R0027000018 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 7        R0027000025 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 8        R0027000030 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 9        R0027000035 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 10       R0027000040 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 11       R0027000047 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 12       R0027000050 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 13       R0027000060 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 14       R0027000065 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 15       R0027000080 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 16       R0027000080 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 17       R0027000085 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 18       R0027000085 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 19       R0027000105 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 20       R0027000112 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 21       R0027000120 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 22       R0027000130 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 23       R0027000135 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 24       R0027000142 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 25       R0027000147 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 26       R0027000150 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 27       R0027000155 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 28       R0027000160 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# 29       R0027000166 2000-01-01        ABBS SUB  CENTRAL BOISE BENCH
# ...              ...        ...             ...                  ...
# 1200881  S1124212495 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200882  S1124212550 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200883  S1124233600 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200884  S1124233640 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200885  S1124233650 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200886  S1124314850 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200887  S1124314900 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200888  S1124314900 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200889  S1124325475 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200890  S1124325550 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200891  S1124325570 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200892  S1124325700 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200893  S1124325700 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200894  S1124325825 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200895  S1124325825 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200896  S1124325850 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200897  S1124336050 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200898  S1124336201 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200899  S1124336272 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200900  S1124336310 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200901  S1124336320 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200902  S1124336350 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200903  S1124346621 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200904  S1124346803 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200905  S1124346852 2018-01-01        3N 1E 24      SOUTHWEST BOISE
# 1200906  S1503111004 2018-01-01        2N 2E 03   SOUTH BOISE DESERT
# 1200907  S1506231100 2018-01-01        2N 2E 06   SOUTH BOISE DESERT
# 1200908  S1506234000 2018-01-01        2N 2E 06   SOUTH BOISE DESERT
# 1200909  S1604449750 2018-01-01        2N 3E 04         OREGON TRAIL
# 1200910  S1618234875 2018-01-01        2N 3E 18   SOUTH BOISE DESERT
#
#                 Area  Age  Bedroom_Count  Bathroom_Count    TAV_Ch  \
# 0            W BOISE    2              4            4.00  0.000000
# 1            W BOISE    1              4            4.00  0.000000
# 2            W BOISE    1              4            4.00  0.000000
# 3            W BOISE    2              4            4.00  0.000000
# 4        BOISE BENCH   63              1            1.25  0.000000
# 5        BOISE BENCH   63              4            1.75  0.000000
# 6        BOISE BENCH   63              2            0.75  0.000000
# 7        BOISE BENCH   50              2            0.75  0.000000
# 8        BOISE BENCH   50              1            0.75  0.000000
# 9        BOISE BENCH   59              2            2.00  0.000000
# 10       BOISE BENCH   51              4            2.50  0.000000
# 11       BOISE BENCH   52              4            1.25  0.000000
# 12       BOISE BENCH   50              3            1.00  0.000000
# 13       BOISE BENCH   54              3            1.00  0.000000
# 14       BOISE BENCH   65              3            0.75  0.000000
# 15       BOISE BENCH   62              2            0.75  0.000000
# 16       BOISE BENCH   62              2            0.75  0.000000
# 17       BOISE BENCH   50              2            0.75  0.000000
# 18       BOISE BENCH   50              1            0.75  0.000000
# 19       BOISE BENCH   50              2            1.00  0.000000
# 20       BOISE BENCH   17              3            1.75  0.000000
# 21       BOISE BENCH   48              4            1.50  0.000000
# 22       BOISE BENCH   23              3            1.75  0.000000
# 23       BOISE BENCH   65              2            1.00  0.000000
# 24       BOISE BENCH   61              2            0.75  0.000000
# 25       BOISE BENCH    9              4            2.25  0.000000
# 26       BOISE BENCH   20              3            3.50  0.000000
# 27       BOISE BENCH   65              3            2.00  0.000000
# 28       BOISE BENCH   29              3            1.00  0.000000
# 29       BOISE BENCH   65              4            1.25  0.000000
# ...              ...  ...            ...             ...       ...
# 1200881     SW BOISE   88              3            1.75  0.159330
# 1200882     SW BOISE   59              3            1.00  0.169134
# 1200883     SW BOISE   35              3            2.75  0.205694
# 1200884     SW BOISE   48              3            2.00  0.204102
# 1200885     SW BOISE   47              3            1.50  0.212623
# 1200886     SW BOISE   27              3            3.00  0.110045
# 1200887     SW BOISE   48              3            1.75  0.102883
# 1200888     SW BOISE   42              1            1.00  0.000000
# 1200889     SW BOISE   25              3            2.50  0.096491
# 1200890     SW BOISE   45              2            2.00  0.117098
# 1200891     SW BOISE   72              4            1.75  0.141478
# 1200892     SW BOISE   42              4            1.75  0.154523
# 1200893     SW BOISE   46              3            1.75  0.000000
# 1200894     SW BOISE  108              2            0.75  0.160464
# 1200895     SW BOISE   72              2            1.00  0.000000
# 1200896     SW BOISE   15              3            2.00  0.112996
# 1200897     SW BOISE   50              3            1.75  0.101384
# 1200898     SW BOISE   42              3            1.50  0.117846
# 1200899     SW BOISE   42              3            1.50  0.133630
# 1200900     SW BOISE   47              3            2.00  0.441495
# 1200901     SW BOISE   50              3            1.75  0.160873
# 1200902     SW BOISE   46              3            1.75  0.136792
# 1200903     SW BOISE   55              4            1.75  0.076126
# 1200904     SW BOISE   47              3            1.50  0.082915
# 1200905     SW BOISE   40              4            2.50  0.109628
# 1200906     SW BOISE  108              2            1.50  0.073737
# 1200907     SW BOISE   21              3            2.50  0.067365
# 1200908     SW BOISE   78              2            1.00  1.395262
# 1200909     SE BOISE   13              5            3.50  0.137213
# 1200910     SE BOISE   46              3            2.50  0.048216
#
#          Architecture And Engineering Occupations  ...  \
# 0                                        0.000000  ...
# 1                                        0.000000  ...
# 2                                        0.000000  ...
# 3                                        0.000000  ...
# 4                                        0.000000  ...
# 5                                        0.000000  ...
# 6                                        0.000000  ...
# 7                                        0.000000  ...
# 8                                        0.000000  ...
# 9                                        0.000000  ...
# 10                                       0.000000  ...
# 11                                       0.000000  ...
# 12                                       0.000000  ...
# 13                                       0.000000  ...
# 14                                       0.000000  ...
# 15                                       0.000000  ...
# 16                                       0.000000  ...
# 17                                       0.000000  ...
# 18                                       0.000000  ...
# 19                                       0.000000  ...
# 20                                       0.000000  ...
# 21                                       0.000000  ...
# 22                                       0.000000  ...
# 23                                       0.000000  ...
# 24                                       0.000000  ...
# 25                                       0.000000  ...
# 26                                       0.000000  ...
# 27                                       0.000000  ...
# 28                                       0.000000  ...
# 29                                       0.000000  ...
# ...                                           ...  ...
# 1200881                                  0.052561  ...
# 1200882                                  0.052561  ...
# 1200883                                  0.052561  ...
# 1200884                                  0.052561  ...
# 1200885                                  0.052561  ...
# 1200886                                  0.052561  ...
# 1200887                                  0.052561  ...
# 1200888                                  0.052561  ...
# 1200889                                  0.052561  ...
# 1200890                                  0.052561  ...
# 1200891                                  0.052561  ...
# 1200892                                  0.052561  ...
# 1200893                                  0.052561  ...
# 1200894                                  0.052561  ...
# 1200895                                  0.052561  ...
# 1200896                                  0.052561  ...
# 1200897                                  0.052561  ...
# 1200898                                  0.052561  ...
# 1200899                                  0.052561  ...
# 1200900                                  0.052561  ...
# 1200901                                  0.052561  ...
# 1200902                                  0.052561  ...
# 1200903                                  0.052561  ...
# 1200904                                  0.052561  ...
# 1200905                                  0.052561  ...
# 1200906                                  0.052561  ...
# 1200907                                  0.052561  ...
# 1200908                                  0.052561  ...
# 1200909                                  0.052561  ...
# 1200910                                  0.052561  ...
#
#          Transportation And Material Moving Occupations  (10000.0, 40000.0]  \
# 0                                              0.000000            0.000000
# 1                                              0.000000            0.000000
# 2                                              0.000000            0.000000
# 3                                              0.000000            0.000000
# 4                                              0.000000            0.000000
# 5                                              0.000000            0.000000
# 6                                              0.000000            0.000000
# 7                                              0.000000            0.000000
# 8                                              0.000000            0.000000
# 9                                              0.000000            0.000000
# 10                                             0.000000            0.000000
# 11                                             0.000000            0.000000
# 12                                             0.000000            0.000000
# 13                                             0.000000            0.000000
# 14                                             0.000000            0.000000
# 15                                             0.000000            0.000000
# 16                                             0.000000            0.000000
# 17                                             0.000000            0.000000
# 18                                             0.000000            0.000000
# 19                                             0.000000            0.000000
# 20                                             0.000000            0.000000
# 21                                             0.000000            0.000000
# 22                                             0.000000            0.000000
# 23                                             0.000000            0.000000
# 24                                             0.000000            0.000000
# 25                                             0.000000            0.000000
# 26                                             0.000000            0.000000
# 27                                             0.000000            0.000000
# 28                                             0.000000            0.000000
# 29                                             0.000000            0.000000
# ...                                                 ...                 ...
# 1200881                                        0.128488            0.012748
# 1200882                                        0.128488            0.012748
# 1200883                                        0.128488            0.012748
# 1200884                                        0.128488            0.012748
# 1200885                                        0.128488            0.012748
# 1200886                                        0.128488            0.012748
# 1200887                                        0.128488            0.012748
# 1200888                                        0.128488            0.012748
# 1200889                                        0.128488            0.012748
# 1200890                                        0.128488            0.012748
# 1200891                                        0.128488            0.012748
# 1200892                                        0.128488            0.012748
# 1200893                                        0.128488            0.012748
# 1200894                                        0.128488            0.012748
# 1200895                                        0.128488            0.012748
# 1200896                                        0.128488            0.012748
# 1200897                                        0.128488            0.012748
# 1200898                                        0.128488            0.012748
# 1200899                                        0.128488            0.012748
# 1200900                                        0.128488            0.012748
# 1200901                                        0.128488            0.012748
# 1200902                                        0.128488            0.012748
# 1200903                                        0.128488            0.012748
# 1200904                                        0.128488            0.012748
# 1200905                                        0.128488            0.012748
# 1200906                                        0.128488            0.012748
# 1200907                                        0.128488            0.012748
# 1200908                                        0.128488            0.012748
# 1200909                                        0.128488            0.012748
# 1200910                                        0.128488            0.012748
#
#          (40000.0, 70000.0]  (70000.0, 100000.0]  (100000.0, 150000.0]  \
# 0                  0.000000              0.00000              0.000000
# 1                  0.000000              0.00000              0.000000
# 2                  0.000000              0.00000              0.000000
# 3                  0.000000              0.00000              0.000000
# 4                  0.000000              0.00000              0.000000
# 5                  0.000000              0.00000              0.000000
# 6                  0.000000              0.00000              0.000000
# 7                  0.000000              0.00000              0.000000
# 8                  0.000000              0.00000              0.000000
# 9                  0.000000              0.00000              0.000000
# 10                 0.000000              0.00000              0.000000
# 11                 0.000000              0.00000              0.000000
# 12                 0.000000              0.00000              0.000000
# 13                 0.000000              0.00000              0.000000
# 14                 0.000000              0.00000              0.000000
# 15                 0.000000              0.00000              0.000000
# 16                 0.000000              0.00000              0.000000
# 17                 0.000000              0.00000              0.000000
# 18                 0.000000              0.00000              0.000000
# 19                 0.000000              0.00000              0.000000
# 20                 0.000000              0.00000              0.000000
# 21                 0.000000              0.00000              0.000000
# 22                 0.000000              0.00000              0.000000
# 23                 0.000000              0.00000              0.000000
# 24                 0.000000              0.00000              0.000000
# 25                 0.000000              0.00000              0.000000
# 26                 0.000000              0.00000              0.000000
# 27                 0.000000              0.00000              0.000000
# 28                 0.000000              0.00000              0.000000
# 29                 0.000000              0.00000              0.000000
# ...                     ...                  ...                   ...
# 1200881            0.100524              0.03221              0.280519
# 1200882            0.100524              0.03221              0.280519
# 1200883            0.100524              0.03221              0.280519
# 1200884            0.100524              0.03221              0.280519
# 1200885            0.100524              0.03221              0.280519
# 1200886            0.100524              0.03221              0.280519
# 1200887            0.100524              0.03221              0.280519
# 1200888            0.100524              0.03221              0.280519
# 1200889            0.100524              0.03221              0.280519
# 1200890            0.100524              0.03221              0.280519
# 1200891            0.100524              0.03221              0.280519
# 1200892            0.100524              0.03221              0.280519
# 1200893            0.100524              0.03221              0.280519
# 1200894            0.100524              0.03221              0.280519
# 1200895            0.100524              0.03221              0.280519
# 1200896            0.100524              0.03221              0.280519
# 1200897            0.100524              0.03221              0.280519
# 1200898            0.100524              0.03221              0.280519
# 1200899            0.100524              0.03221              0.280519
# 1200900            0.100524              0.03221              0.280519
# 1200901            0.100524              0.03221              0.280519
# 1200902            0.100524              0.03221              0.280519
# 1200903            0.100524              0.03221              0.280519
# 1200904            0.100524              0.03221              0.280519
# 1200905            0.100524              0.03221              0.280519
# 1200906            0.100524              0.03221              0.280519
# 1200907            0.100524              0.03221              0.280519
# 1200908            0.100524              0.03221              0.280519
# 1200909            0.100524              0.03221              0.280519
# 1200910            0.100524              0.03221              0.280519
#
#          (150000.0, 200000.0]  (200000.0, 300000.0]  Total_House_Change  \
# 0                         0.0              0.000000            0.000000
# 1                         0.0              0.000000            0.000000
# 2                         0.0              0.000000            0.000000
# 3                         0.0              0.000000            0.000000
# 4                         0.0              0.000000            0.000000
# 5                         0.0              0.000000            0.000000
# 6                         0.0              0.000000            0.000000
# 7                         0.0              0.000000            0.000000
# 8                         0.0              0.000000            0.000000
# 9                         0.0              0.000000            0.000000
# 10                        0.0              0.000000            0.000000
# 11                        0.0              0.000000            0.000000
# 12                        0.0              0.000000            0.000000
# 13                        0.0              0.000000            0.000000
# 14                        0.0              0.000000            0.000000
# 15                        0.0              0.000000            0.000000
# 16                        0.0              0.000000            0.000000
# 17                        0.0              0.000000            0.000000
# 18                        0.0              0.000000            0.000000
# 19                        0.0              0.000000            0.000000
# 20                        0.0              0.000000            0.000000
# 21                        0.0              0.000000            0.000000
# 22                        0.0              0.000000            0.000000
# 23                        0.0              0.000000            0.000000
# 24                        0.0              0.000000            0.000000
# 25                        0.0              0.000000            0.000000
# 26                        0.0              0.000000            0.000000
# 27                        0.0              0.000000            0.000000
# 28                        0.0              0.000000            0.000000
# 29                        0.0              0.000000            0.000000
# ...                       ...                   ...                 ...
# 1200881                   0.0             -0.148515            0.028322
# 1200882                   0.0             -0.148515            0.028322
# 1200883                   0.0             -0.148515            0.028322
# 1200884                   0.0             -0.148515            0.028322
# 1200885                   0.0             -0.148515            0.028322
# 1200886                   0.0             -0.148515            0.028322
# 1200887                   0.0             -0.148515            0.028322
# 1200888                   0.0             -0.148515            0.028322
# 1200889                   0.0             -0.148515            0.028322
# 1200890                   0.0             -0.148515            0.028322
# 1200891                   0.0             -0.148515            0.028322
# 1200892                   0.0             -0.148515            0.028322
# 1200893                   0.0             -0.148515            0.028322
# 1200894                   0.0             -0.148515            0.028322
# 1200895                   0.0             -0.148515            0.028322
# 1200896                   0.0             -0.148515            0.028322
# 1200897                   0.0             -0.148515            0.028322
# 1200898                   0.0             -0.148515            0.028322
# 1200899                   0.0             -0.148515            0.028322
# 1200900                   0.0             -0.148515            0.028322
# 1200901                   0.0             -0.148515            0.028322
# 1200902                   0.0             -0.148515            0.028322
# 1200903                   0.0             -0.148515            0.028322
# 1200904                   0.0             -0.148515            0.028322
# 1200905                   0.0             -0.148515            0.028322
# 1200906                   0.0             -0.148515            0.028322
# 1200907                   0.0             -0.148515            0.028322
# 1200908                   0.0             -0.148515            0.028322
# 1200909                   0.0             -0.148515            0.028322
# 1200910                   0.0             -0.148515            0.028322
#
#          Total_Pop_Change  Total_Emp_Change
# 0                0.000000           0.00000
# 1                0.000000           0.00000
# 2                0.000000           0.00000
# 3                0.000000           0.00000
# 4                0.000000           0.00000
# 5                0.000000           0.00000
# 6                0.000000           0.00000
# 7                0.000000           0.00000
# 8                0.000000           0.00000
# 9                0.000000           0.00000
# 10               0.000000           0.00000
# 11               0.000000           0.00000
# 12               0.000000           0.00000
# 13               0.000000           0.00000
# 14               0.000000           0.00000
# 15               0.000000           0.00000
# 16               0.000000           0.00000
# 17               0.000000           0.00000
# 18               0.000000           0.00000
# 19               0.000000           0.00000
# 20               0.000000           0.00000
# 21               0.000000           0.00000
# 22               0.000000           0.00000
# 23               0.000000           0.00000
# 24               0.000000           0.00000
# 25               0.000000           0.00000
# 26               0.000000           0.00000
# 27               0.000000           0.00000
# 28               0.000000           0.00000
# 29               0.000000           0.00000
# ...                   ...               ...
# 1200881          0.028653           0.04332
# 1200882          0.028653           0.04332
# 1200883          0.028653           0.04332
# 1200884          0.028653           0.04332
# 1200885          0.028653           0.04332
# 1200886          0.028653           0.04332
# 1200887          0.028653           0.04332
# 1200888          0.028653           0.04332
# 1200889          0.028653           0.04332
# 1200890          0.028653           0.04332
# 1200891          0.028653           0.04332
# 1200892          0.028653           0.04332
# 1200893          0.028653           0.04332
# 1200894          0.028653           0.04332
# 1200895          0.028653           0.04332
# 1200896          0.028653           0.04332
# 1200897          0.028653           0.04332
# 1200898          0.028653           0.04332
# 1200899          0.028653           0.04332
# 1200900          0.028653           0.04332
# 1200901          0.028653           0.04332
# 1200902          0.028653           0.04332
# 1200903          0.028653           0.04332
# 1200904          0.028653           0.04332
# 1200905          0.028653           0.04332
# 1200906          0.028653           0.04332
# 1200907          0.028653           0.04332
# 1200908          0.028653           0.04332
# 1200909          0.028653           0.04332
# 1200910          0.028653           0.04332
#
# [1200911 rows x 40 columns]

# %% [markdown]
# # Build Area Correlation Coefficient
# use k= 11 because TAV_Ch to TAV_Ch = 1

# %%
def coefComp(area, df):
    k = 11
    df_Fun = df.copy()
    df_Fun = df_Fun[df_Fun['Area'] == area]
    corrmat = df_Fun.corr()
    cols = corrmat.nlargest(k, 'TAV_Ch')['TAV_Ch']
    temp = pd.DataFrame(cols)

    return temp

# %%
# Area

df = pd.read_pickle('AN_Build.pkl')

temp = list(df.columns)
aBoise = pd.DataFrame(temp)
aBoise = aBoise.rename(columns = {0 : 'index'})

df1 = coefComp('NW BOISE-GARDEN CITY', df)
df1 = df1.reset_index()
aBoise = pd.merge(aBoise,df1, on = 'index', how = 'left')
aBoise = aBoise.rename(columns = {'TAV_Ch' : 'NW_Boise_GC'})

df2 = coefComp('BOISE BENCH', df)
df2 = df2.reset_index()
aBoise = pd.merge(aBoise,df2, on = 'index', how = 'left')
aBoise = aBoise.rename(columns = {'TAV_Ch' : 'B_Bench'})

df3 = coefComp('SE BOISE', df)
df3 = df3.reset_index()
aBoise = pd.merge(aBoise,df3, on = 'index', how = 'left')
aBoise = aBoise.rename(columns = {'TAV_Ch' : 'SE_Boise'})

df4 = coefComp('NORTH BOISE', df)
df4 = df4.reset_index()
aBoise = pd.merge(aBoise,df4, on = 'index', how = 'left')
aBoise = aBoise.rename(columns = {'TAV_Ch' : 'N_Boise'})

df5 = coefComp('NE BOISE', df)
df5 = df5.reset_index()
aBoise = pd.merge(aBoise,df5, on = 'index', how = 'left')
aBoise = aBoise.rename(columns = {'TAV_Ch' : 'NE_Boise'})

df6 = coefComp('W BOISE', df)
df6 = df6.reset_index()
aBoise = pd.merge(aBoise,df6, on = 'index', how = 'left')
aBoise = aBoise.rename(columns = {'TAV_Ch' : 'W_Boise'})

df7 = coefComp('SW BOISE-MERIDIAN', df)
df7 = df7.reset_index()
aBoise = pd.merge(aBoise,df7, on = 'index', how = 'left')
aBoise = aBoise.rename(columns = {'TAV_Ch' : 'SW_Boise_M'})

df8 = coefComp('W BOISE-MERIDIAN', df)
df8 = df8.reset_index()
aBoise = pd.merge(aBoise,df8, on = 'index', how = 'left')
aBoise = aBoise.rename(columns = {'TAV_Ch' : 'W_Boise_M'})

df9 = coefComp('SW BOISE', df)
df9 = df9.reset_index()
aBoise = pd.merge(aBoise,df9, on = 'index', how = 'left')
aBoise = aBoise.rename(columns = {'TAV_Ch' : 'SW_Boise'})


aBoise.to_pickle('a-Coeff-compare.pkl')

# %%
df = aBoise
df = df.iloc[9:]
df = df.reset_index(drop = True)
df = df.reset_index(drop = False)
df = df.dropna(thresh = 3)
df['level_0'] = df['level_0'].to_string()

df
#type(df.iloc[0,0])
#df.iloc[0,0]
# Out:
#                                               level_0  \
# 1   1      1\n2      2\n9      9\n12    12\n15    ...
# 2   1      1\n2      2\n9      9\n12    12\n15    ...
# 9   1      1\n2      2\n9      9\n12    12\n15    ...
# 12  1      1\n2      2\n9      9\n12    12\n15    ...
# 15  1      1\n2      2\n9      9\n12    12\n15    ...
# 18  1      1\n2      2\n9      9\n12    12\n15    ...
# 20  1      1\n2      2\n9      9\n12    12\n15    ...
# 21  1      1\n2      2\n9      9\n12    12\n15    ...
# 24  1      1\n2      2\n9      9\n12    12\n15    ...
# 28  1      1\n2      2\n9      9\n12    12\n15    ...
# 29  1      1\n2      2\n9      9\n12    12\n15    ...
# 30  1      1\n2      2\n9      9\n12    12\n15    ...
#
#                                                 index  NW_Boise_GC   B_Bench  \
# 1   Arts, Design, Entertainment, Sports, And Media...     0.205122  0.322296
# 2   Building And Grounds Cleaning And Maintenance ...     0.202024  0.297780
# 9    Food Preparation And Serving Related Occupations     0.155807  0.262860
# 12  Installation, Maintenance, And Repair Occupations          NaN       NaN
# 15                             Management Occupations     0.202974  0.296489
# 18                             Production Occupations     0.171633  0.272514
# 20                      Sales And Related Occupations     0.207232  0.336855
# 21     Transportation And Material Moving Occupations     0.192655  0.312932
# 24                                (70000.0, 100000.0]          NaN       NaN
# 28                                 Total_House_Change     0.210065  0.308301
# 29                                   Total_Pop_Change     0.198068  0.309162
# 30                                   Total_Emp_Change     0.219423  0.341163
#
#     SE_Boise   N_Boise  NE_Boise   W_Boise  SW_Boise_M  W_Boise_M  SW_Boise
# 1   0.151652  0.145686       NaN  0.295192    0.150496   0.172005  0.220358
# 2   0.173484  0.161233  0.031920  0.304118    0.198560   0.190496  0.210010
# 9        NaN  0.142039  0.026809       NaN    0.160731   0.168292  0.178493
# 12       NaN       NaN  0.023058       NaN         NaN        NaN       NaN
# 15  0.157372  0.161072  0.028292  0.279548    0.156382   0.187270       NaN
# 18  0.137178       NaN  0.029265  0.258399    0.147523   0.169168  0.186179
# 20  0.169741  0.177855  0.031064  0.306431    0.186115   0.193440  0.247814
# 21  0.146978  0.167256  0.024673  0.275292    0.162169   0.188961  0.194388
# 24  0.142206  0.142631       NaN  0.230002         NaN        NaN  0.169268
# 28  0.177842  0.198513  0.028786  0.283742    0.147697   0.196804  0.198978
# 29  0.173615  0.205515  0.031775  0.279665    0.156102   0.192057  0.192903
# 30  0.178943  0.175049  0.035173  0.316577    0.187518   0.215725  0.215771

# %% [markdown]
# # Build Neighborhood Correlation Coefficient
# use k= 11 because TAV_Ch to TAV_Ch = 1

# %%
def NcoefComp(neigh, df):
    k = 11
    df_Fun = df.copy()
    df_Fun = df_Fun[df_Fun['Neighborhood'] == neigh]
    corrmat = df_Fun.corr()
    cols = corrmat.nlargest(k, 'TAV_Ch')['TAV_Ch']
    temp = pd.DataFrame(cols)

    return temp

# %%
# W BOISE AREA NEIGHBORHOODS

Adf = pd.read_pickle('AN_Build.pkl')
Adf = Adf[Adf['Area'] == 'W BOISE']

temp = list(Adf.columns)
df = pd.DataFrame(temp)
df = df.rename(columns = {0 : 'index'})

df1 = NcoefComp('NORTH CENTRAL BENCH', Adf)
df1 = df1.reset_index()
df = pd.merge(df,df1, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'WB_NC_Bench'})


df2 = NcoefComp('WEST BOISE', Adf)
df2 = df2.reset_index()
df = pd.merge(df,df2, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'WB_W_Boise'})

df3 = NcoefComp('WEST BOISE FREEWAY CORRIDOR', Adf)
df3 = df3.reset_index()
df = pd.merge(df,df3, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'WB_WBF_Corridor'})


df.to_pickle('WB-Coeff-compare.pkl')
#df

# %%
# BOISE BENCH AREA NEIGHBORHOODS

Adf = pd.read_pickle('AN_Build.pkl')
Adf = Adf[Adf['Area'] == 'BOISE BENCH']

temp = list(Adf.columns)
df = pd.DataFrame(temp)
df = df.rename(columns = {0 : 'index'})

df1 = NcoefComp('CENTRAL BOISE BENCH', Adf)
df1 = df1.reset_index()
df = pd.merge(df,df1, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'BB_CB_Bench'})


df2 = NcoefComp('NORTH CENTRAL BENCH', Adf)
df2 = df2.reset_index()
df = pd.merge(df,df2, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'BB_NC_Bench'})

df3 = NcoefComp('BOISE BENCH FREEWAY CORRIDOR', Adf)
df3 = df3.reset_index()
df = pd.merge(df,df3, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'BB_BBF_Corridor'})

df4 = NcoefComp('PARK & UNIVERSITY WATERFRONT', Adf)
df4 = df4.reset_index()
df = pd.merge(df,df4, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'BB_PU_Waterfront'})

df.to_pickle('BB-Coeff-compare.pkl')
#df

# %%
# W BOISE-MERIDIAN AREA NEIGHBORHOODS

Adf = pd.read_pickle('AN_Build.pkl')
Adf = Adf[Adf['Area'] == 'W BOISE-MERIDIAN']

temp = list(Adf.columns)
df = pd.DataFrame(temp)
df = df.rename(columns = {0 : 'index'})

df1 = NcoefComp('WEST BOISE', Adf)
df1 = df1.reset_index()
df = pd.merge(df,df1, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'WBM_W_Boise'})

df2 = NcoefComp('NORTHEAST MERIDIAN', Adf)
df2 = df2.reset_index()
df = pd.merge(df,df2, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'WBM_NE_Meridian'})

df3 = NcoefComp('WEST BOISE FREEWAY CORRIDOR', Adf)
df3 = df3.reset_index()
df = pd.merge(df,df3, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'WBM_WBF_Corridor'})

df4 = NcoefComp('NORTH CENTRAL BENCH', Adf)
df4 = df4.reset_index()
df = pd.merge(df,df4, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'WBM_NC_Bench'})

df5 = NcoefComp('GARDEN CITY CHINDEN CORRIDOR', Adf)
df5 = df5.reset_index()
df = pd.merge(df,df5, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'WBM_GCC_Corridor'})

df6 = NcoefComp('MERIDIAN FREEWAY CORRIDOR', Adf)
df6 = df6.reset_index()
df = pd.merge(df,df6, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'WBM_MF_Corridor'})

df.to_pickle('WBM-Coeff-compare.pkl')
#df

# %%
# NORTH BOISE AREA NEIGHBORHOODS

Adf = pd.read_pickle('AN_Build.pkl')
Adf = Adf[Adf['Area'] == 'NORTH BOISE']

temp = list(Adf.columns)
df = pd.DataFrame(temp)
df = df.rename(columns = {0 : 'index'})

df1 = NcoefComp('OLD NORTH BOISE', Adf)
df1 = df1.reset_index()
df = pd.merge(df,df1, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'NB_Old_N_Boise'})

df2 = NcoefComp('BOISE FOOTHILLS', Adf)
df2 = df2.reset_index()
df = pd.merge(df,df2, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'NB_B_Foothills'})

df3 = NcoefComp('NEW NORTH BOISE', Adf)
df3 = df3.reset_index()
df = pd.merge(df,df3, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'NB_New_N_Boise'})

df4 = NcoefComp('DOWNTOWN BOISE', Adf)
df4 = df4.reset_index()
df = pd.merge(df,df4, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'NB_Downtown'})

df5 = NcoefComp('WARM SPRINGS', Adf)
df5 = df5.reset_index()
df = pd.merge(df,df5, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'NB_Warm_Springs'})

df6 = NcoefComp('PARK & UNIVERSITY WATERFRONT', Adf)
df6 = df6.reset_index()
df = pd.merge(df,df6, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'NB_PU_Waterfront'})

df.to_pickle('NB-Coeff-compare.pkl')
#df

# %%
# SE BOISE AREA NEIGHBORHOODS

Adf = pd.read_pickle('AN_Build.pkl')
Adf = Adf[Adf['Area'] == 'SE BOISE']

temp = list(Adf.columns)
df = pd.DataFrame(temp)
df = df.rename(columns = {0 : 'index'})

df1 = NcoefComp('NEW SOUTHEAST BOISE', Adf)
df1 = df1.reset_index()
df = pd.merge(df,df1, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'SE_New_SE_Boise'})

df2 = NcoefComp('SOUTHEAST BOISE INFILL', Adf)
df2 = df2.reset_index()
df = pd.merge(df,df2, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'SE_SE_Boise_Infill'})

df3 = NcoefComp('EAST BOISE WATERFRONT', Adf)
df3 = df3.reset_index()
df = pd.merge(df,df3, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'SE_E_Boise_Waterfront'})

df4 = NcoefComp('OREGON TRAIL', Adf)
df4 = df4.reset_index()
df = pd.merge(df,df4, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'SE_Oregon_Trail'})

df5 = NcoefComp('PARK & UNIVERSITY WATERFRONT', Adf)
df5 = df5.reset_index()
df = pd.merge(df,df5, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'SE_PU_Waterfront'})

df6 = NcoefComp('SOUTH BOISE DESERT', Adf)
df6 = df6.reset_index()
df = pd.merge(df,df6, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'SE_S_Boise_Desert'})

df.to_pickle('SE-Coeff-compare.pkl')
#df

# %%
# NW BOISE-GARDIN CITY AREA NEIGHBORHOODS

Adf = pd.read_pickle('AN_Build.pkl')
Adf = Adf[Adf['Area'] == 'NW BOISE-GARDEN CITY']

temp = list(Adf.columns)
df = pd.DataFrame(temp)
df = df.rename(columns = {0 : 'index'})

df1 = NcoefComp('NEW NORTH BOISE', Adf)
df1 = df1.reset_index()
df = pd.merge(df,df1, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'NW_New_N_Boise'})

df2 = NcoefComp('NORTHWEST BOISE', Adf)
df2 = df2.reset_index()
df = pd.merge(df,df2, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'NW_NW_Boise'})

df3 = NcoefComp('GARDEN CITY WATERFRONT', Adf)
df3 = df3.reset_index()
df = pd.merge(df,df3, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'NW_GC_Waterfront'})

df4 = NcoefComp('BOISE FOOTHILLS', Adf)
df4 = df4.reset_index()
df = pd.merge(df,df4, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'NW_B_Foothills'})

df5 = NcoefComp('GARDEN CITY CHINDEN CORRIDOR', Adf)
df5 = df5.reset_index()
df = pd.merge(df,df5, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'NW_GCC_Corridor'})


df.to_pickle('NW-Coeff-compare.pkl')
#df

# %%
# NE BOISE AREA NEIGHBORHOODS

Adf = pd.read_pickle('AN_Build.pkl')
Adf = Adf[Adf['Area'] == 'NE BOISE']

temp = list(Adf.columns)
df = pd.DataFrame(temp)
df = df.rename(columns = {0 : 'index'})

df1 = NcoefComp('BOISE FOOTHILLS', Adf)
df1 = df1.reset_index()
df = pd.merge(df,df1, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'NE_B_Foothills'})

df2 = NcoefComp('WARM SPRINGS', Adf)
df2 = df2.reset_index()
df = pd.merge(df,df2, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'NE_Warm_Springs'})

df3 = NcoefComp('EAST BOISE WATERFRONT', Adf)
df3 = df3.reset_index()
df = pd.merge(df,df3, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'NE_E_Boise_Waterfront'})

df4 = NcoefComp('BARBER & HARRIS RANCH', Adf)
df4 = df4.reset_index()
df = pd.merge(df,df4, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'NE_Barber_Harris_Ranch'})


df.to_pickle('NE-Coeff-compare.pkl')
#df

# %%
# SW BOISE AREA NEIGHBORHOODS

Adf = pd.read_pickle('AN_Build.pkl')
Adf = Adf[Adf['Area'] == 'SW BOISE']

temp = list(Adf.columns)
df = pd.DataFrame(temp)
df = df.rename(columns = {0 : 'index'})

df1 = NcoefComp('WEST BOISE FREEWAY CORRIDOR', Adf)
df1 = df1.reset_index()
df = pd.merge(df,df1, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'SW_WBF_Corridor'})

df2 = NcoefComp('AIRPORT', Adf)
df2 = df2.reset_index()
df = pd.merge(df,df2, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'SW_Airport'})

df3 = NcoefComp('BOISE BENCH FREEWAY CORRIDOR', Adf)
df3 = df3.reset_index()
df = pd.merge(df,df3, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'SE_BBF_Corridor'})

df4 = NcoefComp('SOUTH BOISE DESERT', Adf)
df4 = df4.reset_index()
df = pd.merge(df,df4, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'SW_B_Desert'})

df5 = NcoefComp('SOUTHWEST BOISE', Adf)
df5 = df5.reset_index()
df = pd.merge(df,df5, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'SW_SW_Boise'})


df.to_pickle('SW-Coeff-compare.pkl')
#df

# %%
# SW BOISE-MERIDIAN AREA NEIGHBORHOODS

Adf = pd.read_pickle('AN_Build.pkl')
Adf = Adf[Adf['Area'] == 'SW BOISE-MERIDIAN']

temp = list(Adf.columns)
df = pd.DataFrame(temp)
df = df.rename(columns = {0 : 'index'})

df1 = NcoefComp('WEST BOISE FREEWAY CORRIDOR', Adf)
df1 = df1.reset_index()
df = pd.merge(df,df1, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'SWBM_WBF_Corridor'})

df2 = NcoefComp('MERIDIAN FREEWAY CORRIDOR', Adf)
df2 = df2.reset_index()
df = pd.merge(df,df2, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'SWBM_MF_Corridor'})

df3 = NcoefComp('SOUTH MERIDIAN', Adf)
df3 = df3.reset_index()
df = pd.merge(df,df3, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'SWBM_S_Meridian'})

df4 = NcoefComp('SOUTHWEST BOISE', Adf)
df4 = df4.reset_index()
df = pd.merge(df,df4, on = 'index', how = 'left')
df = df.rename(columns = {'TAV_Ch' : 'SWBM_SW_Boise'})


df.to_pickle('SWBM-Coeff-compare.pkl')
#df
